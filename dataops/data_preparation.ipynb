# %%
import os
import shutil

# %%
# Define the path to the main folder containing all sensor data
main_folder = 'Carla_Data'
# Define the path to the folder where all images will be saved
output_folder = 'Test_Images'

# %%
# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
# Initialize a counter for naming the images
counter = 1

# Walk through the directory structure
for root, dirs, files in os.walk(main_folder):
    for file in files:
        # Check if the file is a PNG image
        if file.endswith('.png'):
            # Extract the full path to the image
            full_image_path = os.path.join(root, file)
            print(full_image_path)

            # Extract the folder and camera name from the path
            folder_name = os.path.basename(os.path.dirname(root))
            print(folder_name)
            camera_name = os.path.basename(root).replace('camera_', '')
            print(camera_name)

            # Split the folder name into its components
            folder_parts = folder_name.split('_')
            print(folder_parts)

            # Extract town number (e.g., "02" from "town_02")
            town_number = folder_parts[3]
            print(town_number)

            # Determine part number or default to "00" if not present
            if 'part' in folder_parts:
                part_index = folder_parts.index('part')
                print(part_index)
                part_number = folder_parts[part_index + 1]
                print(f'The part number is {part_number}')
                time_of_day = folder_parts[part_index + 2]
                print(time_of_day)
            else:
                part_number = '00'
                print(f'The part number is {part_number}')
                time_of_day = folder_parts[6]
                print(time_of_day)

            # Create the new filename using the placeholders
            new_filename = f"{counter:04d}_town_{town_number}_part_{part_number}_{time_of_day}_{camera_name}.png"
            print(new_filename)

            # Define the full path for the new image location
            # new_image_path = os.path.join(output_folder, new_filename)

            # Copy and rename the image to the output folder
            # shutil.copyfile(full_image_path, new_image_path)

            break
# Out:
# Carla_Data/sensor_data_town_01_part_00_morning/camera_left_rear/3381.png
# sensor_data_town_01_part_00_morning
# left_rear
# ['sensor', 'data', 'town', '01', 'part', '00', 'morning']
# 01
# 4
# The part number is 00
# morning
# 0001_town_01_part_00_morning_left_rear.png
# Carla_Data/sensor_data_town_01_part_00_morning/camera_front_fisheye/3381.png
# sensor_data_town_01_part_00_morning
# front_fisheye
# ['sensor', 'data', 'town', '01', 'part', '00', 'morning']
# 01
# 4
# The part number is 00
# morning
# 0001_town_01_part_00_morning_front_fisheye.png
# Carla_Data/sensor_data_town_01_part_00_morning/camera_rear/3381.png
# sensor_data_town_01_part_00_morning
# rear
# ['sensor', 'data', 'town', '01', 'part', '00', 'morning']
# 01
# 4
# The part number is 00
# morning
# 0001_town_01_part_00_morning_rear.png
# Carla_Data/sensor_data_town_01_part_00_morning/camera_right_forward/3381.png
# sensor_data_town_01_part_00_morning
# right_forward
# ['sensor', 'data', 'town', '01', 'part', '00', 'morning']
# 01
# 4
# The part number is 00
# morning
# 0001_town_01_part_00_morning_right_forward.png
# Carla_Data/sensor_data_town_01_part_00_morning/camera_front_wide/3381.png
# sensor_data_town_01_part_00_morning
# front_wide
# ['sensor', 'data', 'town', '01', 'part', '00', 'morning']
# 01
# 4
# The part number is 00
# morning
# 0001_town_01_part_00_morning_front_wide.png
# Carla_Data/sensor_data_town_01_part_00_morning/camera_front_narrow/3381.png
# sensor_data_town_01_part_00_morning
# front_narrow
# ['sensor', 'data', 'town', '01', 'part', '00', 'morning']
# 01
# 4
# The part number is 00
# morning
# 0001_town_01_part_00_morning_front_narrow.png
# Carla_Data/sensor_data_town_01_part_00_morning/camera_left_forward/3381.png
# sensor_data_town_01_part_00_morning
# left_forward
# ['sensor', 'data', 'town', '01', 'part', '00', 'morning']
# 01
# 4
# The part number is 00
# morning
# 0001_town_01_part_00_morning_left_forward.png
# Carla_Data/sensor_data_town_01_part_00_morning/camera_right_rear/3381.png
# sensor_data_town_01_part_00_morning
# right_rear
# ['sensor', 'data', 'town', '01', 'part', '00', 'morning']
# 01
# 4
# The part number is 00
# morning
# 0001_town_01_part_00_morning_right_rear.png
# Carla_Data/sensor_data_town_06_part_00_midday/camera_left_rear/3020.png
# sensor_data_town_06_part_00_midday
# left_rear
# ['sensor', 'data', 'town', '06', 'part', '00', 'midday']
# 06
# 4
# The part number is 00
# midday
# 0001_town_06_part_00_midday_left_rear.png
# Carla_Data/sensor_data_town_06_part_00_midday/camera_front_fisheye/3020.png
# sensor_data_town_06_part_00_midday
# front_fisheye
# ['sensor', 'data', 'town', '06', 'part', '00', 'midday']
# 06
# 4
# The part number is 00
# midday
# 0001_town_06_part_00_midday_front_fisheye.png
# Carla_Data/sensor_data_town_06_part_00_midday/camera_rear/3020.png
# sensor_data_town_06_part_00_midday
# rear
# ['sensor', 'data', 'town', '06', 'part', '00', 'midday']
# 06
# 4
# The part number is 00
# midday
# 0001_town_06_part_00_midday_rear.png
# Carla_Data/sensor_data_town_06_part_00_midday/camera_right_forward/3020.png
# sensor_data_town_06_part_00_midday
# right_forward
# ['sensor', 'data', 'town', '06', 'part', '00', 'midday']
# 06
# 4
# The part number is 00
# midday
# 0001_town_06_part_00_midday_right_forward.png
# Carla_Data/sensor_data_town_06_part_00_midday/camera_front_wide/3020.png
# sensor_data_town_06_part_00_midday
# front_wide
# ['sensor', 'data', 'town', '06', 'part', '00', 'midday']
# 06
# 4
# The part number is 00
# midday
# 0001_town_06_part_00_midday_front_wide.png
# Carla_Data/sensor_data_town_06_part_00_midday/camera_front_narrow/3020.png
# sensor_data_town_06_part_00_midday
# front_narrow
# ['sensor', 'data', 'town', '06', 'part', '00', 'midday']
# 06
# 4
# The part number is 00
# midday
# 0001_town_06_part_00_midday_front_narrow.png
# Carla_Data/sensor_data_town_06_part_00_midday/camera_left_forward/3020.png
# sensor_data_town_06_part_00_midday
# left_forward
# ['sensor', 'data', 'town', '06', 'part', '00', 'midday']
# 06
# 4
# The part number is 00
# midday
# 0001_town_06_part_00_midday_left_forward.png
# Carla_Data/sensor_data_town_06_part_00_midday/camera_right_rear/3020.png
# sensor_data_town_06_part_00_midday
# right_rear
# ['sensor', 'data', 'town', '06', 'part', '00', 'midday']
# 06
# 4
# The part number is 00
# midday
# 0001_town_06_part_00_midday_right_rear.png
# Carla_Data/sensor_data_town_01_part_00_night/camera_left_rear/3961.png
# sensor_data_town_01_part_00_night
# left_rear
# ['sensor', 'data', 'town', '01', 'part', '00', 'night']
# 01
# 4
# The part number is 00
# night
# 0001_town_01_part_00_night_left_rear.png
# Carla_Data/sensor_data_town_01_part_00_night/camera_front_fisheye/3961.png
# sensor_data_town_01_part_00_night
# front_fisheye
# ['sensor', 'data', 'town', '01', 'part', '00', 'night']
# 01
# 4
# The part number is 00
# night
# 0001_town_01_part_00_night_front_fisheye.png
# Carla_Data/sensor_data_town_01_part_00_night/camera_rear/3961.png
# sensor_data_town_01_part_00_night
# rear
# ['sensor', 'data', 'town', '01', 'part', '00', 'night']
# 01
# 4
# The part number is 00
# night
# 0001_town_01_part_00_night_rear.png
# Carla_Data/sensor_data_town_01_part_00_night/camera_right_forward/3961.png
# sensor_data_town_01_part_00_night
# right_forward
# ['sensor', 'data', 'town', '01', 'part', '00', 'night']
# 01
# 4
# The part number is 00
# night
# 0001_town_01_part_00_night_right_forward.png
# Carla_Data/sensor_data_town_01_part_00_night/camera_front_wide/3961.png
# sensor_data_town_01_part_00_night
# front_wide
# ['sensor', 'data', 'town', '01', 'part', '00', 'night']
# 01
# 4
# The part number is 00
# night
# 0001_town_01_part_00_night_front_wide.png
# Carla_Data/sensor_data_town_01_part_00_night/camera_front_narrow/3961.png
# sensor_data_town_01_part_00_night
# front_narrow
# ['sensor', 'data', 'town', '01', 'part', '00', 'night']
# 01
# 4
# The part number is 00
# night
# 0001_town_01_part_00_night_front_narrow.png
# Carla_Data/sensor_data_town_01_part_00_night/camera_left_forward/3961.png
# sensor_data_town_01_part_00_night
# left_forward
# ['sensor', 'data', 'town', '01', 'part', '00', 'night']
# 01
# 4
# The part number is 00
# night
# 0001_town_01_part_00_night_left_forward.png
# Carla_Data/sensor_data_town_01_part_00_night/camera_right_rear/3961.png
# sensor_data_town_01_part_00_night
# right_rear
# ['sensor', 'data', 'town', '01', 'part', '00', 'night']
# 01
# 4
# The part number is 00
# night
# 0001_town_01_part_00_night_right_rear.png
# Carla_Data/sensor_data_town_05_part_00_night/camera_left_rear/1151.png
# sensor_data_town_05_part_00_night
# left_rear
# ['sensor', 'data', 'town', '05', 'part', '00', 'night']
# 05
# 4
# The part number is 00
# night
# 0001_town_05_part_00_night_left_rear.png
# Carla_Data/sensor_data_town_05_part_00_night/camera_front_fisheye/1151.png
# sensor_data_town_05_part_00_night
# front_fisheye
# ['sensor', 'data', 'town', '05', 'part', '00', 'night']
# 05
# 4
# The part number is 00
# night
# 0001_town_05_part_00_night_front_fisheye.png
# Carla_Data/sensor_data_town_05_part_00_night/camera_rear/1151.png
# sensor_data_town_05_part_00_night
# rear
# ['sensor', 'data', 'town', '05', 'part', '00', 'night']
# 05
# 4
# The part number is 00
# night
# 0001_town_05_part_00_night_rear.png
# Carla_Data/sensor_data_town_05_part_00_night/camera_right_forward/1151.png
# sensor_data_town_05_part_00_night
# right_forward
# ['sensor', 'data', 'town', '05', 'part', '00', 'night']
# 05
# 4
# The part number is 00
# night
# 0001_town_05_part_00_night_right_forward.png
# Carla_Data/sensor_data_town_05_part_00_night/camera_front_wide/1151.png
# sensor_data_town_05_part_00_night
# front_wide
# ['sensor', 'data', 'town', '05', 'part', '00', 'night']
# 05
# 4
# The part number is 00
# night
# 0001_town_05_part_00_night_front_wide.png
# Carla_Data/sensor_data_town_05_part_00_night/camera_front_narrow/1151.png
# sensor_data_town_05_part_00_night
# front_narrow
# ['sensor', 'data', 'town', '05', 'part', '00', 'night']
# 05
# 4
# The part number is 00
# night
# 0001_town_05_part_00_night_front_narrow.png
# Carla_Data/sensor_data_town_05_part_00_night/camera_left_forward/1151.png
# sensor_data_town_05_part_00_night
# left_forward
# ['sensor', 'data', 'town', '05', 'part', '00', 'night']
# 05
# 4
# The part number is 00
# night
# 0001_town_05_part_00_night_left_forward.png
# Carla_Data/sensor_data_town_05_part_00_night/camera_right_rear/1151.png
# sensor_data_town_05_part_00_night
# right_rear
# ['sensor', 'data', 'town', '05', 'part', '00', 'night']
# 05
# 4
# The part number is 00
# night
# 0001_town_05_part_00_night_right_rear.png
# Carla_Data/sensor_data_town_02_part_01_morning/camera_left_rear/1569.png
# sensor_data_town_02_part_01_morning
# left_rear
# ['sensor', 'data', 'town', '02', 'part', '01', 'morning']
# 02
# 4
# The part number is 01
# morning
# 0001_town_02_part_01_morning_left_rear.png
# Carla_Data/sensor_data_town_02_part_01_morning/camera_front_fisheye/1569.png
# sensor_data_town_02_part_01_morning
# front_fisheye
# ['sensor', 'data', 'town', '02', 'part', '01', 'morning']
# 02
# 4
# The part number is 01
# morning
# 0001_town_02_part_01_morning_front_fisheye.png
# Carla_Data/sensor_data_town_02_part_01_morning/camera_rear/1569.png
# sensor_data_town_02_part_01_morning
# rear
# ['sensor', 'data', 'town', '02', 'part', '01', 'morning']
# 02
# 4
# The part number is 01
# morning
# 0001_town_02_part_01_morning_rear.png
# Carla_Data/sensor_data_town_02_part_01_morning/camera_right_forward/1569.png
# sensor_data_town_02_part_01_morning
# right_forward
# ['sensor', 'data', 'town', '02', 'part', '01', 'morning']
# 02
# 4
# The part number is 01
# morning
# 0001_town_02_part_01_morning_right_forward.png
# Carla_Data/sensor_data_town_02_part_01_morning/camera_front_wide/1569.png
# sensor_data_town_02_part_01_morning
# front_wide
# ['sensor', 'data', 'town', '02', 'part', '01', 'morning']
# 02
# 4
# The part number is 01
# morning
# 0001_town_02_part_01_morning_front_wide.png
# Carla_Data/sensor_data_town_02_part_01_morning/camera_front_narrow/1569.png
# sensor_data_town_02_part_01_morning
# front_narrow
# ['sensor', 'data', 'town', '02', 'part', '01', 'morning']
# 02
# 4
# The part number is 01
# morning
# 0001_town_02_part_01_morning_front_narrow.png
# Carla_Data/sensor_data_town_02_part_01_morning/camera_left_forward/1569.png
# sensor_data_town_02_part_01_morning
# left_forward
# ['sensor', 'data', 'town', '02', 'part', '01', 'morning']
# 02
# 4
# The part number is 01
# morning
# 0001_town_02_part_01_morning_left_forward.png
# Carla_Data/sensor_data_town_02_part_01_morning/camera_right_rear/1569.png
# sensor_data_town_02_part_01_morning
# right_rear
# ['sensor', 'data', 'town', '02', 'part', '01', 'morning']
# 02
# 4
# The part number is 01
# morning
# 0001_town_02_part_01_morning_right_rear.png
# Carla_Data/sensor_data_town_04_part_00_night/camera_left_rear/758.png
# sensor_data_town_04_part_00_night
# left_rear
# ['sensor', 'data', 'town', '04', 'part', '00', 'night']
# 04
# 4
# The part number is 00
# night
# 0001_town_04_part_00_night_left_rear.png
# Carla_Data/sensor_data_town_04_part_00_night/camera_front_fisheye/758.png
# sensor_data_town_04_part_00_night
# front_fisheye
# ['sensor', 'data', 'town', '04', 'part', '00', 'night']
# 04
# 4
# The part number is 00
# night
# 0001_town_04_part_00_night_front_fisheye.png
# Carla_Data/sensor_data_town_04_part_00_night/camera_rear/758.png
# sensor_data_town_04_part_00_night
# rear
# ['sensor', 'data', 'town', '04', 'part', '00', 'night']
# 04
# 4
# The part number is 00
# night
# 0001_town_04_part_00_night_rear.png
# Carla_Data/sensor_data_town_04_part_00_night/camera_right_forward/758.png
# sensor_data_town_04_part_00_night
# right_forward
# ['sensor', 'data', 'town', '04', 'part', '00', 'night']
# 04
# 4
# The part number is 00
# night
# 0001_town_04_part_00_night_right_forward.png
# Carla_Data/sensor_data_town_04_part_00_night/camera_front_wide/758.png
# sensor_data_town_04_part_00_night
# front_wide
# ['sensor', 'data', 'town', '04', 'part', '00', 'night']
# 04
# 4
# The part number is 00
# night
# 0001_town_04_part_00_night_front_wide.png
# Carla_Data/sensor_data_town_04_part_00_night/camera_front_narrow/758.png
# sensor_data_town_04_part_00_night
# front_narrow
# ['sensor', 'data', 'town', '04', 'part', '00', 'night']
# 04
# 4
# The part number is 00
# night
# 0001_town_04_part_00_night_front_narrow.png
# Carla_Data/sensor_data_town_04_part_00_night/camera_left_forward/758.png
# sensor_data_town_04_part_00_night
# left_forward
# ['sensor', 'data', 'town', '04', 'part', '00', 'night']
# 04
# 4
# The part number is 00
# night
# 0001_town_04_part_00_night_left_forward.png
# Carla_Data/sensor_data_town_04_part_00_night/camera_right_rear/758.png
# sensor_data_town_04_part_00_night
# right_rear
# ['sensor', 'data', 'town', '04', 'part', '00', 'night']
# 04
# 4
# The part number is 00
# night
# 0001_town_04_part_00_night_right_rear.png
# Carla_Data/sensor_data_town_05_part_00_morning/camera_left_rear/1384.png
# sensor_data_town_05_part_00_morning
# left_rear
# ['sensor', 'data', 'town', '05', 'part', '00', 'morning']
# 05
# 4
# The part number is 00
# morning
# 0001_town_05_part_00_morning_left_rear.png
# Carla_Data/sensor_data_town_05_part_00_morning/camera_front_fisheye/1384.png
# sensor_data_town_05_part_00_morning
# front_fisheye
# ['sensor', 'data', 'town', '05', 'part', '00', 'morning']
# 05
# 4
# The part number is 00
# morning
# 0001_town_05_part_00_morning_front_fisheye.png
# Carla_Data/sensor_data_town_05_part_00_morning/camera_rear/1384.png
# sensor_data_town_05_part_00_morning
# rear
# ['sensor', 'data', 'town', '05', 'part', '00', 'morning']
# 05
# 4
# The part number is 00
# morning
# 0001_town_05_part_00_morning_rear.png
# Carla_Data/sensor_data_town_05_part_00_morning/camera_right_forward/1384.png
# sensor_data_town_05_part_00_morning
# right_forward
# ['sensor', 'data', 'town', '05', 'part', '00', 'morning']
# 05
# 4
# The part number is 00
# morning
# 0001_town_05_part_00_morning_right_forward.png
# Carla_Data/sensor_data_town_05_part_00_morning/camera_front_wide/1384.png
# sensor_data_town_05_part_00_morning
# front_wide
# ['sensor', 'data', 'town', '05', 'part', '00', 'morning']
# 05
# 4
# The part number is 00
# morning
# 0001_town_05_part_00_morning_front_wide.png
# Carla_Data/sensor_data_town_05_part_00_morning/camera_front_narrow/1384.png
# sensor_data_town_05_part_00_morning
# front_narrow
# ['sensor', 'data', 'town', '05', 'part', '00', 'morning']
# 05
# 4
# The part number is 00
# morning
# 0001_town_05_part_00_morning_front_narrow.png
# Carla_Data/sensor_data_town_05_part_00_morning/camera_left_forward/1384.png
# sensor_data_town_05_part_00_morning
# left_forward
# ['sensor', 'data', 'town', '05', 'part', '00', 'morning']
# 05
# 4
# The part number is 00
# morning
# 0001_town_05_part_00_morning_left_forward.png
# Carla_Data/sensor_data_town_05_part_00_morning/camera_right_rear/1384.png
# sensor_data_town_05_part_00_morning
# right_rear
# ['sensor', 'data', 'town', '05', 'part', '00', 'morning']
# 05
# 4
# The part number is 00
# morning
# 0001_town_05_part_00_morning_right_rear.png
# Carla_Data/sensor_data_town_03_part_00_night/camera_left_rear/638.png
# sensor_data_town_03_part_00_night
# left_rear
# ['sensor', 'data', 'town', '03', 'part', '00', 'night']
# 03
# 4
# The part number is 00
# night
# 0001_town_03_part_00_night_left_rear.png
# Carla_Data/sensor_data_town_03_part_00_night/camera_front_fisheye/638.png
# sensor_data_town_03_part_00_night
# front_fisheye
# ['sensor', 'data', 'town', '03', 'part', '00', 'night']
# 03
# 4
# The part number is 00
# night
# 0001_town_03_part_00_night_front_fisheye.png
# Carla_Data/sensor_data_town_03_part_00_night/camera_rear/638.png
# sensor_data_town_03_part_00_night
# rear
# ['sensor', 'data', 'town', '03', 'part', '00', 'night']
# 03
# 4
# The part number is 00
# night
# 0001_town_03_part_00_night_rear.png
# Carla_Data/sensor_data_town_03_part_00_night/camera_right_forward/638.png
# sensor_data_town_03_part_00_night
# right_forward
# ['sensor', 'data', 'town', '03', 'part', '00', 'night']
# 03
# 4
# The part number is 00
# night
# 0001_town_03_part_00_night_right_forward.png
# Carla_Data/sensor_data_town_03_part_00_night/camera_front_wide/638.png
# sensor_data_town_03_part_00_night
# front_wide
# ['sensor', 'data', 'town', '03', 'part', '00', 'night']
# 03
# 4
# The part number is 00
# night
# 0001_town_03_part_00_night_front_wide.png
# Carla_Data/sensor_data_town_03_part_00_night/camera_front_narrow/638.png
# sensor_data_town_03_part_00_night
# front_narrow
# ['sensor', 'data', 'town', '03', 'part', '00', 'night']
# 03
# 4
# The part number is 00
# night
# 0001_town_03_part_00_night_front_narrow.png
# Carla_Data/sensor_data_town_03_part_00_night/camera_left_forward/638.png
# sensor_data_town_03_part_00_night
# left_forward
# ['sensor', 'data', 'town', '03', 'part', '00', 'night']
# 03
# 4
# The part number is 00
# night
# 0001_town_03_part_00_night_left_forward.png
# Carla_Data/sensor_data_town_03_part_00_night/camera_right_rear/638.png
# sensor_data_town_03_part_00_night
# right_rear
# ['sensor', 'data', 'town', '03', 'part', '00', 'night']
# 03
# 4
# The part number is 00
# night
# 0001_town_03_part_00_night_right_rear.png
# Carla_Data/sensor_data_town_02_part_02_morning/camera_left_rear/2317.png
# sensor_data_town_02_part_02_morning
# left_rear
# ['sensor', 'data', 'town', '02', 'part', '02', 'morning']
# 02
# 4
# The part number is 02
# morning
# 0001_town_02_part_02_morning_left_rear.png
# Carla_Data/sensor_data_town_02_part_02_morning/camera_front_fisheye/2317.png
# sensor_data_town_02_part_02_morning
# front_fisheye
# ['sensor', 'data', 'town', '02', 'part', '02', 'morning']
# 02
# 4
# The part number is 02
# morning
# 0001_town_02_part_02_morning_front_fisheye.png
# Carla_Data/sensor_data_town_02_part_02_morning/camera_rear/2317.png
# sensor_data_town_02_part_02_morning
# rear
# ['sensor', 'data', 'town', '02', 'part', '02', 'morning']
# 02
# 4
# The part number is 02
# morning
# 0001_town_02_part_02_morning_rear.png
# Carla_Data/sensor_data_town_02_part_02_morning/camera_right_forward/2317.png
# sensor_data_town_02_part_02_morning
# right_forward
# ['sensor', 'data', 'town', '02', 'part', '02', 'morning']
# 02
# 4
# The part number is 02
# morning
# 0001_town_02_part_02_morning_right_forward.png
# Carla_Data/sensor_data_town_02_part_02_morning/camera_front_wide/2317.png
# sensor_data_town_02_part_02_morning
# front_wide
# ['sensor', 'data', 'town', '02', 'part', '02', 'morning']
# 02
# 4
# The part number is 02
# morning
# 0001_town_02_part_02_morning_front_wide.png
# Carla_Data/sensor_data_town_02_part_02_morning/camera_front_narrow/2317.png
# sensor_data_town_02_part_02_morning
# front_narrow
# ['sensor', 'data', 'town', '02', 'part', '02', 'morning']
# 02
# 4
# The part number is 02
# morning
# 0001_town_02_part_02_morning_front_narrow.png
# Carla_Data/sensor_data_town_02_part_02_morning/camera_left_forward/2317.png
# sensor_data_town_02_part_02_morning
# left_forward
# ['sensor', 'data', 'town', '02', 'part', '02', 'morning']
# 02
# 4
# The part number is 02
# morning
# 0001_town_02_part_02_morning_left_forward.png
# Carla_Data/sensor_data_town_02_part_02_morning/camera_right_rear/2317.png
# sensor_data_town_02_part_02_morning
# right_rear
# ['sensor', 'data', 'town', '02', 'part', '02', 'morning']
# 02
# 4
# The part number is 02
# morning
# 0001_town_02_part_02_morning_right_rear.png

# %%
import os
import shutil

# Define the path to the main folder containing all sensor data
main_folder = 'Carla_Data'
# Define the path to the folder where all images will be saved
output_folder = 'Dataset_Images_2'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Initialize a counter for naming the images
counter = 1

# Walk through the directory structure
for root, dirs, files in os.walk(main_folder):
    for file in files:
        # Check if the file is a PNG image
        if file.endswith('.png'):
            # Extract the full path to the image
            full_image_path = os.path.join(root, file)

            # Extract the folder and camera name from the path
            folder_name = os.path.basename(os.path.dirname(root))
            camera_name = os.path.basename(root).replace('camera_', '')

            # Split the folder name into its components
            folder_parts = folder_name.split('_')

            # Extract town number (e.g., "02" from "town_02")
            town_number = folder_parts[3]

            # Determine part number or default to "00" if not present
            if 'part' in folder_parts:
                part_index = folder_parts.index('part')
                part_number = folder_parts[part_index + 1]
                time_of_day = folder_parts[part_index + 2]
            else:
                part_number = '00'
                time_of_day = folder_parts[6]

            # Create the new filename using the placeholders
            new_filename = f"{counter:04d}_town_{town_number}_part_{part_number}_{time_of_day}_{camera_name}.png"

            # Define the full path for the new image location
            new_image_path = os.path.join(output_folder, new_filename)

            # Copy and rename the image to the output folder
            shutil.copyfile(full_image_path, new_image_path)

            # Increment the counter for the next image
            counter += 1

print(f"Collected images have been saved to the '{output_folder}' directory.")

# %%
import os

# Define the path to the Collected_Images folder
collected_images_folder = 'Dataset_Images'

# Initialize a counter for the images
image_count = 0

# Walk through the directory structure (in case there are subfolders, though in this case it should be flat)
for root, dirs, files in os.walk(collected_images_folder):
    for file in files:
        # Check if the file is a PNG image
        if file.endswith('.png'):
            image_count += 1

# Output the result
print(f"Total number of images in '{collected_images_folder}': {image_count}")
# Out:
# Total number of images in 'Dataset_Images': 6400
